# %%
# pip install selenium chromedriver_autoinstaller webdriver-manager

# %% [markdown]
# - [파이썬 웹자동화 (1) 셀레니움 설치 및 환경설정, 웹드라이버 자동설치 (크롬드라이버 설치X)](https://itmanual.net/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%9B%B9%EC%9E%90%EB%8F%99%ED%99%94-1-%EC%85%80%EB%A0%88%EB%8B%88%EC%9B%80-%EC%84%A4%EC%B9%98-%EB%B0%8F-%ED%99%98%EA%B2%BD%EC%84%A4%EC%A0%95-%EC%9B%B9%EB%93%9C%EB%9D%BC/)

# %%
import time

# %%
# Selenium 모듈에서 webdriver를 가져옵니다.
from selenium import webdriver 
# Chrome 브라우저 옵션을 다루는 Options 클래스를 가져옵니다.
from selenium.webdriver.chrome.options import Options
# Chrome 드라이버 서비스를 다루는 Service 클래스를 가져옵니다.
from selenium.webdriver.chrome.service import Service
# Chrome 드라이버를 다운로드하고 설치하는 데 사용되는 ChromeDriverManager를 가져옵니다.
from webdriver_manager.chrome import ChromeDriverManager
 
# Options 클래스의 인스턴스를 생성합니다.
options = Options()
 
# Chrome 브라우저 창이 즉시 닫히는 것을 방지합니다.
options.add_experimental_option('detach', True)
 
# 불필요한 콘솔 메시지를 제거합니다.
options.add_experimental_option('excludeSwitches', ['enable-logging'])
 
# Chrome 드라이버 서비스를 생성합니다.
service = Service(ChromeDriverManager().install())

# %%
# Chrome 브라우저를 실행하는 ChromeDriver 객체를 생성합니다.
driver = webdriver.Chrome(service=service, options=options)

# Chrome 브라우저에서 https://itmanual.net 페이지를 로드합니다.
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

# %% [markdown]
# - find_element(By.ID, ‘***’): ID 속성을 사용하여 웹 요소를 찾습니다.
# - find_element(By.NAME, ‘***’): NAME 속성을 사용하여 웹 요소를 찾습니다.
# - find_element(By.CLASS_NAME, ‘***’): CLASS 속성을 사용하여 웹 요소를 찾습니다.
# - find_element(By.TAG_NAME, ‘***’): 태그 이름을 사용하여 웹 요소를 찾습니다.
# - find_element(By.CSS_SELECTOR, ‘***’): CSS 선택자를 사용하여 웹 요소를 찾습니다.
# - find_element(By.XPATH, ‘***’): XPATH를 사용하여 웹 요소를 찾습니다.
#
# - driver.implicitly_wait(10)

# %%
from selenium.webdriver.common.by import By

# %%
# total_data = []
# for s, d in [[1, 99],[100, 100]]:
#     print(s, d)
#     total_data += list(range(s, s+d))

# %%
# 1분야 데이터
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul'
element = driver.find_element(By.XPATH, xpath)
category_1 = {idx:name for idx, name in enumerate(element.text.split('\n'), start=1)}
category_1
# Out:
# {1: '패션의류',
#  2: '패션잡화',
#  3: '화장품/미용',
#  4: '디지털/가전',
#  5: '가구/인테리어',
#  6: '출산/육아',
#  7: '식품',
#  8: '스포츠/레저',
#  9: '생활/건강',
#  10: '여가/생활편의',
#  11: '면세점',
#  12: '도서'}

# %%
# 1분류 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/span'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 출산/육아 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul/li[6]/a'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 2분류 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[2]/span'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 2분야 데이터
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[2]/ul'
element = driver.find_element(By.XPATH, xpath)
category_1 = {idx:name for idx, name in enumerate(element.text.split('\n'), start=1)}
category_1
# Out:
# {1: '분유',
#  2: '기저귀',
#  3: '물티슈',
#  4: '이유식',
#  5: '아기간식',
#  6: '수유용품',
#  7: '유모차',
#  8: '카시트',
#  9: '외출용품',
#  10: '목욕용품',
#  11: '스킨/바디용품',
#  12: '위생/건강용품',
#  13: '구강청결용품',
#  14: '유아세제',
#  15: '소독/살균용품',
#  16: '안전용품',
#  17: '유아가구',
#  18: '이유식용품',
#  19: '임부복',
#  20: '임산부용품',
#  21: '유아침구',
#  22: '출산/돌기념품',
#  23: '신생아의류',
#  24: '유아동의류',
#  25: '유아동언더웨어/잠옷',
#  26: '유아동잡화',
#  27: '수영복/용품',
#  28: '유아동 주얼리',
#  29: '유아발육용품',
#  30: '완구/매트',
#  31: '인형',
#  32: '교구'}

# %%
# 아기간식 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[2]/ul/li[5]/a'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 3분류 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[3]/span'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 3분야 데이터
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[3]/ul'
element = driver.find_element(By.XPATH, xpath)
category_1 = {idx:name for idx, name in enumerate(element.text.split('\n'), start=1)}
category_1
# Out:
# {1: '유아두유', 2: '유아과자', 3: '유아유제품', 4: '유아음료'}

# %%
# 아기간식 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[3]/ul/li[4]/a'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 1년 기간 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[1]/span/label[3]'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 기기별 전체 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[3]/div/div/span[1]'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 성별 여성 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[4]/div/div/span[2]'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 연령 30대, 40대 클릭
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[5]/div/div/span[4]'
element = driver.find_element(By.XPATH, xpath)
element.click()
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[5]/div/div/span[5]'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
# 조회하기
xpath = '//*[@id="content"]/div[2]/div/div[1]/div/a'
element = driver.find_element(By.XPATH, xpath)
element.click()

# %%
total_ls = []

# 인기 검색어 리스트 20개 가져오기
xpath = '//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[1]/ul'
element = driver.find_element(By.XPATH, xpath)
data = element.text.split('\n')
ls = list(zip(data[0::2], data[1::2]))
total_ls += ls
# print(ls[0])

for _ in range(24):
    # 다음 페이지 이동
    xpath = '//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/a[2]'
    element = driver.find_element(By.XPATH, xpath)
    element.click()
    time.sleep(1)
    
    # 인기 검색어 리스트 20개 가져오기
    xpath = '//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[1]/ul'
    element = driver.find_element(By.XPATH, xpath)
    data = element.text.split('\n')
    ls = list(zip(data[0::2], data[1::2]))
    total_ls += ls
    # print(ls[0])

# %%
if len(total_ls) == 500 & len(set(total_ls))==500:
    print('s')
# Out:
# s

# %%
total_ls
# Out:
# [('1', '뽀로로음료수'),
#  ('2', '아기보리차'),
#  ('3', '뽀로로보리차'),
#  ('4', '아기배도라지즙'),
#  ('5', '루솔진한배도라지즙'),
#  ('6', '요미요미'),
#  ('7', '뽀로로음료'),
#  ('8', '아이키커'),
#  ('9', '뽀로로워터젤리'),
#  ('10', '끙아주스'),
#  ('11', '베베쿡배도라지'),
#  ('12', '요미요미주스'),
#  ('13', '엘빈즈배도라지'),
#  ('14', '아기배도라지'),
#  ('15', '크니쁘니'),
#  ('16', '배도라지'),
#  ('17', '뽀로로주스'),
#  ('18', '아기배도라지차'),
#  ('19', '유기농하늘보리'),
#  ('20', '뽀로로쥬스'),
#  ('21', '베베쿡보리차'),
#  ('22', '베이비워터'),
#  ('23', '요미요미배도라지'),
#  ('24', '요미요미유기농주스'),
#  ('25', '뽀로로누룽지차'),
#  ('26', '유아배도라지즙'),
#  ('27', '아기주스'),
#  ('28', '총명하이배도라지차'),
#  ('29', '배도라지즙아기'),
#  ('30', '아기작두콩차'),
#  ('31', '코코몽보리차'),
#  ('32', '아기보리차티백'),
#  ('33', '와일드알프'),
#  ('34', '오가닉디노'),
#  ('35', '유아음료'),
#  ('36', '정관장아이키커'),
#  ('37', '뽀로로샤인머스캣'),
#  ('38', '코코몽하늘보리'),
#  ('39', '총명하이'),
#  ('40', '아기푸룬주스'),
#  ('41', '뽀로로밀크맛'),
#  ('42', '아기쥬스'),
#  ('43', '루솔작두콩보리차'),
#  ('44', '유아보리차'),
#  ('45', '뽀로로비타플러스'),
#  ('46', '크니쁘니주스'),
#  ('47', '브레드이발소키즈홍삼'),
# ...

# %%
driver.close()
