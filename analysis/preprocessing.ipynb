# %%
from text_preprocessing import TextPreprocessing
import pandas as pd

# %%
model = TextPreprocessing()

# %%
model._preprocssing('')

# %%
pd.read_excel('../data/list.xlsx')
# Out:
#       Unnamed: 0  0         1          2  \
# 0              0  5  bara****  23.05.10.
# 1              1  4  li******  21.09.23.
# 2              2  5  k*k*****  22.10.19.
# 3              3  5  g*u*****  23.04.26.
# 4              4  5  y*r*****  22.11.25.
# ...          ... ..       ...        ...
# 3982        3982  5  skbr****  20.09.30.
# 3983        3983  5  okdk****  23.04.29.
# 3984        3984  4  d*k*****  22.12.02.
# 3985        3985  5  g*r*****  22.03.31.
# 3986        3986  5  jkyo****  21.04.03.
#
#                                                       3
# 0     간편하게 먹을수 있어서 자주 사게 되네요~\n홍삼즙은 1년내내 잘 먹고 있으면서 활...
# 1     상품이야 검증된 제품이니 별 문제 없는데 배송은 엉망이네요 저희 동네에 도착은 전일...
# 2                         조아요조아요조아요 조아요조아요조아요 조아요조아요조아요
# 3                  저렴하게 구매해서 좋습니다.유통기한도 넉넉합니다.주문 강추입니다.
# 4     선물하려고 구매했는데 배송도 빠르고 유효기간도 길어서 만족합니다. 저렴하게 잘 샀어...
# ...                                                 ...
# 3982  부모님 선물드렸는데 너무 좋아하세요.\n내용물이 매우 고급져서 선물드리는 뽀대가 납니다.
# ...
